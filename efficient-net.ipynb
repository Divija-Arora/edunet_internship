# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/eeeeee/efficientnetv2-s_notop.h5
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/vad/images (4).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/vad/download (3).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/vad/download (4).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/vad/images (27).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/vad/images.jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/vad/images (23).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/vad/download (9).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/vad/download (7).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/vad/images (9).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/vad/images (7).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/vad/images (19).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/vad/images (33).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/vad/images (16).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/vad/images (11).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/vad/images (21).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/vad/download (11).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/vad/images (24).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/vad/download (6).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/vad/images (13).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/vad/download (12).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/vad/images (17).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/vad/download.jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/vad/images (25).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/vad/download (1).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/vad/images (12).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/vad/images (1).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/vad/download (15).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/vad/images (28).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/vad/download (5).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/vad/download (10).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/vad/images (14).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/vad/images (22).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/vad/images (30).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/vad/images (26).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/vad/images (29).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/vad/images (8).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/vad/images (15).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/vad/images (6).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/vad/images (34).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/vad/images (2).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/vad/images (5).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/vad/images (10).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/vad/images (20).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/vad/images (32).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/vad/images (18).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/vad/images (31).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/vad/images (3).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/vad/download (8).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/vad/download (2).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/vad/download (13).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/saptaparni/image27.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/saptaparni/image2.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/saptaparni/image47.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/saptaparni/image40.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/saptaparni/image34.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/saptaparni/image36.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/saptaparni/image42.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/saptaparni/image46.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/saptaparni/image43.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/saptaparni/image39.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/saptaparni/image25.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/saptaparni/image26.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/saptaparni/image1.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/saptaparni/image17.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/saptaparni/image11.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/saptaparni/image12.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/saptaparni/image3.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/saptaparni/image20.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/saptaparni/image48.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/saptaparni/image44.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/saptaparni/image6.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/saptaparni/image14.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/saptaparni/image45.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/saptaparni/image37.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/saptaparni/image21.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/saptaparni/image31.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/saptaparni/image15.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/saptaparni/image22.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/saptaparni/image30.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/saptaparni/image23.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/saptaparni/image4.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/saptaparni/image9.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/saptaparni/image29.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/saptaparni/image8.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/saptaparni/image49.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/saptaparni/image32.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/saptaparni/image18.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/saptaparni/image5.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/saptaparni/image41.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/saptaparni/image10.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/saptaparni/image16.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/saptaparni/image28.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/saptaparni/image35.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/saptaparni/image13.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/saptaparni/image19.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/saptaparni/image7.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/saptaparni/image24.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/saptaparni/image50.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/saptaparni/image33.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/saptaparni/image38.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/kanchan/images (2).jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/kanchan/images (4).jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/kanchan/download (3).jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/kanchan/images (13).jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/kanchan/images.jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/kanchan/240_F_815640135_Cv31bAD7NT8dwVRbsNBiFWEgxgNxpmBt.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/kanchan/images (9).jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/kanchan/240_F_572498418_NlT2gk9wl74w5hLcuj6VNdhY8qEjkPwW.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/kanchan/images (22).jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/kanchan/240_F_728700009_ykW4kiiJyYuiqem147uVjoNr4CAKsOdG.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/kanchan/download (7).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/kanchan/240_F_368610928_11QZ7ce2hT0kzE0lLWlP577btSyBsOPk.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/kanchan/images (5).jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/kanchan/images (19).jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/kanchan/images (10).jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/kanchan/images (23).jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/kanchan/images (6).jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/kanchan/images (25).jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/kanchan/images (16).jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/kanchan/images (11).jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/kanchan/images (8).jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/kanchan/download (5).jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/kanchan/download.jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/kanchan/download (1).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/kanchan/download (6).jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/kanchan/240_F_711267494_xjFdasxwkZUEKl2687kAi0fozTb7JzT2.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/kanchan/images (20).jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/kanchan/images (24).jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/kanchan/images (18).jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/kanchan/240_F_794850235_lo8VCoXhsVZQjj6xZOw0RruSgiTIsBe4.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/
jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/kesudo/images (19).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/kesudo/images (33).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/kesudo/images (16).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/kesudo/images (11).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/kesudo/images (21).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/kesudo/images (24).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/kesudo/images (13).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/kesudo/images (17).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/kesudo/download.jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/kesudo/images (25).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/kesudo/images (45).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/kesudo/download (1).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/kesudo/images (12).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/kesudo/images (1).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/kesudo/images (28).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/kesudo/download (5).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/kesudo/images (14).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/kesudo/images (22).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/kesudo/images (30).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/kesudo/images (35).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/kesudo/images (39).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/kesudo/images (38).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/kesudo/images (26).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/kesudo/images (29).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/kesudo/images (8).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/kesudo/images (15).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/kesudo/images (6).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/kesudo/images (34).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/kesudo/images (2).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/kesudo/images (5).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/kesudo/images (41).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/kesudo/images (10).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/kesudo/images (36).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/kesudo/images (20).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/kesudo/images (32).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/kesudo/images (18).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/kesudo/images (31).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/kesudo/images (3).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/kesudo/images (37).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/kesudo/images (44).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/kesudo/images (42).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/kesudo/download (2).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/mango/image27.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/mango/20.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/mango/6.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/mango/image47.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/mango/image40.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/mango/image34.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/mango/5.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/mango/image36.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/mango/8.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/mango/image42.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/mango/image46.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/mango/10.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/mango/image43.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/mango/image39.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/mango/9.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/mango/1.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/mango/download.jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/mango/image26.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/mango/16.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/mango/23.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/mango/7.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/mango/22.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/mango/image48.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/mango/image44.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/mango/24.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/mango/image45.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/mango/image37.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/mango/image31.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/mango/13.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/mango/image30.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/mango/17.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/mango/15.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/mango/12.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/mango/image29.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/mango/11.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/mango/image49.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/mango/image32.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/mango/21.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/mango/4.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/mango/3.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/mango/image41.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/mango/image28.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/mango/image35.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/mango/19.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/mango/14.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/mango/18.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/mango/image33.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/mango/2.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/mango/image38.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/mango/25.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/asopalav/images (4).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/asopalav/download (3).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/asopalav/download (4).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/asopalav/images (27).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/asopalav/images.jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/asopalav/images (23).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/asopalav/images (40).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/asopalav/images (9).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/asopalav/images (7).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/asopalav/images (19).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/asopalav/images (33).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/asopalav/images (16).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/asopalav/images (11).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/asopalav/images (21).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/asopalav/1.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/asopalav/images (24).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/asopalav/images (13).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/asopalav/images (17).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/asopalav/download.jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/asopalav/images (25).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/asopalav/download (1).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/asopalav/images (12).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/asopalav/images (1).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/asopalav/images (28).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/asopalav/images (14).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/asopalav/images (22).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/asopalav/images (30).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/asopalav/images (35).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/asopalav/images (39).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/asopalav/images (38).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/asopalav/images (26).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/asopalav/images (29).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/asopalav/images (8).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/asopalav/images (15).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/asopalav/images (6).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/asopalav/images (34).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/asopalav/images (2).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/asopalav/4.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/asopalav/images (5).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/asopalav/images (10).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/asopalav/images (36).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/asopalav/3.jpg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/asopalav/images (20).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/asopalav/images (32).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/asopalav/images (18).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/asopalav/images (31).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/asopalav/images (3).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/asopalav/images (37).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/asopalav/download (2).jpeg
# /kaggle/input/tree-species-dataset/Tree_Species_Dataset/asopalav/2.jpg

# %%
import os
len(os.listdir("/kaggle/input/tree-species-dataset/Tree_Species_Dataset"))
# Out:
# 31

# %%
import os
import glob

repo_path = "/kaggle/input/tree-species-dataset/Tree_Species_Dataset"

image_paths = []
labels = []

for class_name in os.listdir(repo_path):
    class_folder = os.path.join(repo_path, class_name)
    if os.path.isdir(class_folder):
        for img_file in os.listdir(class_folder):
            image_paths.append(os.path.join(class_folder, img_file))
            labels.append(class_name)

print(f"Total images: {len(image_paths)}")
# Out:
# Total images: 1605

# %%
import pandas as pd

repo_path = "/kaggle/input/tree-species-dataset/Tree_Species_Dataset"
class_dirs = os.listdir(repo_path)

class_counts = {cls: len(os.listdir(os.path.join(repo_path, cls))) for cls in class_dirs}
class_counts_df = pd.DataFrame.from_dict(class_counts, orient='index', columns=['Image Count'])

print(class_counts_df.sort_values('Image Count', ascending=False).head())
print("shape: ", class_counts_df.shape)
# Out:
#             Image Count
# other               150
# saptaparni           50
# vad                  50
# kanchan              50
# champa               50
# shape:  (31, 1)

# %%
from PIL import Image
import os
import pandas as pd

image_shapes = []

for class_dir in class_dirs:
    class_path = os.path.join(repo_path, class_dir)
    for img_file in os.listdir(class_path):
        img_path = os.path.join(class_path, img_file)

        try:
            img = Image.open(img_path)
            image_shapes.append(img.size)
        except:
            pass  # silently skip unreadable/corrupt images

shapes_df = pd.DataFrame(image_shapes, columns=["Width", "Height"])
shapes_df.head()
# Out:
#    Width  Height
# 0    194     259
# 1    251     201
# 2    225     225
# 3    259     194
# 4    225     225

# %%
print(shapes_df.describe())
# Out:
#              Width       Height
# count  1600.000000  1600.000000
# mean    312.623125   269.821875
# std     296.220501   278.014229
# min     141.000000   128.000000
# 25%     225.000000   183.000000
# 50%     259.000000   200.000000
# 75%     275.000000   259.000000
# max    4000.000000  4032.000000

# %%
image_info = []

for class_dir in class_dirs:
    class_path = os.path.join(repo_path, class_dir)
    for img_file in os.listdir(class_path):
        img_path = os.path.join(class_path, img_file)
        try:
            with Image.open(img_path) as img:
                width, height = img.size
                image_info.append({
                    'path': img_path,
                    'width': width,
                    'height': height,
                    'class': class_dir
                })
        except:
            continue

df_sizes = pd.DataFrame(image_info)
print(df_sizes[['width', 'height']].describe())
# torture the data until it reveals everything
# Out:
#              width       height
# count  1600.000000  1600.000000
# mean    312.623125   269.821875
# std     296.220501   278.014229
# min     141.000000   128.000000
# 25%     225.000000   183.000000
# 50%     259.000000   200.000000
# 75%     275.000000   259.000000
# max    4000.000000  4032.000000

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator


# Define parameters
IMG_HEIGHT = 224
IMG_WIDTH = 224
BATCH_SIZE = 32

# Augmentation and rescaling
datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2,
    rotation_range=20,
    zoom_range=0.2,
    shear_range=0.2,
    horizontal_flip=True
)

train_gen = datagen.flow_from_directory(
    repo_path,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='training'
)

val_gen = datagen.flow_from_directory(
    repo_path,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='validation'
)
# Out:
# 2025-08-02 17:04:37.685428: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1754154277.910624      36 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1754154277.978700      36 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Found 1280 images belonging to 31 classes.
# Found 320 images belonging to 31 classes.

# %%
import tensorflow as tf
from tensorflow.keras.applications.efficientnet_v2 import EfficientNetV2S, preprocess_input

folder_path='/kaggle/input/tree-species-dataset/Tree_Species_Dataset'

train_ds=tf.keras.preprocessing.image_dataset_from_directory(
    folder_path,
    validation_split=0.2,
    shuffle=True,
    label_mode='int',
    seed=42,
    batch_size=32,
    subset='training',
    image_size=(384, 384)
)

test_ds=tf.keras.preprocessing.image_dataset_from_directory(
    folder_path,
    validation_split=0.2,
    label_mode='int',
    subset='validation',
    seed=42,
    batch_size=32,
    image_size=(384, 384)
)

AUTOTUNE=tf.data.AUTOTUNE
train_ds=train_ds.map(lambda x,y:(preprocess_input(x),y),num_parallel_calls=AUTOTUNE)
test_ds=test_ds.map(lambda x,y:(preprocess_input(x),y),num_parallel_calls=AUTOTUNE)

train_ds=train_ds.cache().prefetch(buffer_size=AUTOTUNE)
test_ds=test_ds.cache().prefetch(buffer_size=AUTOTUNE)
# Out:
# Found 1600 files belonging to 30 classes.
# Using 1280 files for training.
# I0000 00:00:1754154295.263548      36 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1754154295.264305      36 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Found 1600 files belonging to 30 classes.
# Using 320 files for validation.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.applications import EfficientNetV2S
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam

base_model = EfficientNetV2S(
    include_top=False,
   weights='/kaggle/input/eeeeee/efficientnetv2-s_notop.h5', 
   # weights='imagenet',
    input_shape=(384, 384, 3),
    pooling='avg'
)

model=Sequential()
model.add(base_model)
model.add(Dense(128,activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(64,activation='relu',kernel_regularizer=l2(0.001)))
model.add(BatchNormalization())
model.add(Dropout(0.3))
model.add(Dense(30,activation='softmax'))

model.compile(optimizer=Adam(learning_rate=0.0009),loss='sparse_categorical_crossentropy',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ efficientnetv2-s (Functional)   │ (None, 1280)           │    20,331,360 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       163,968 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 30)             │         1,950 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 20,506,302 (78.23 MB)
#  Trainable params: 20,352,046 (77.64 MB)
#  Non-trainable params: 154,256 (602.56 KB)

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stop = EarlyStopping(
    monitor='val_accuracy',
    patience=10,
    restore_best_weights=True,
    mode='max',
    verbose=1
)

history = model.fit(
    train_ds,
    validation_data=test_ds,
    epochs=28,
    callbacks=[early_stop])
# Out:
# Epoch 1/28
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1754154430.836866     121 service.cc:148] XLA service 0x7d4600052bf0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1754154430.837991     121 service.cc:156]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1754154430.838011     121 service.cc:156]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1754154441.820992     121 cuda_dnn.cc:529] Loaded cuDNN version 90300
# E0000 00:00:1754154466.282609     121 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754154466.453319     121 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754154467.284373     121 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754154467.466339     121 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754154468.176446     121 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754154468.329210     121 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# I0000 00:00:1754154507.082624     121 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 239s 1s/step - accuracy: 0.0954 - loss: 3.7370 - val_accuracy: 0.3688 - val_loss: 2.6646
# Epoch 2/28
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 36s 909ms/step - accuracy: 0.3197 - loss: 2.5719 - val_accuracy: 0.5594 - val_loss: 1.9895
# Epoch 3/28
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 38s 943ms/step - accuracy: 0.5151 - loss: 1.8342 - val_accuracy: 0.6344 - val_loss: 1.6349
# Epoch 4/28
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 36s 906ms/step - accuracy: 0.6334 - loss: 1.4709 - val_accuracy: 0.7219 - val_loss: 1.2947
# Epoch 5/28
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 37s 925ms/step - accuracy: 0.7362 - loss: 1.1359 - val_accuracy: 0.7688 - val_loss: 1.0547
# Epoch 6/28
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 37s 916ms/step - accuracy: 0.8053 - loss: 0.8875 - val_accuracy: 0.7781 - val_loss: 1.0152
# Epoch 7/28
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 37s 923ms/step - accuracy: 0.8870 - loss: 0.6607 - val_accuracy: 0.7937 - val_loss: 0.9174
# Epoch 8/28
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 37s 918ms/step - accuracy: 0.9076 - loss: 0.5605 - val_accuracy: 0.7406 - val_loss: 1.1197
# Epoch 9/28
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 36s 911ms/step - accuracy: 0.9155 - loss: 0.4949 - val_accuracy: 0.7688 - val_loss: 1.0106
# Epoch 10/28
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 36s 911ms/step - accuracy: 0.9138 - loss: 0.4656 - val_accuracy: 0.7750 - val_loss: 1.1480
# Epoch 11/28
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 37s 915ms/step - accuracy: 0.9056 - loss: 0.5482 - val_accuracy: 0.6531 - val_loss: 1.5910
# Epoch 12/28
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 37s 917ms/step - accuracy: 0.8727 - loss: 0.6349 - val_accuracy: 0.7375 - val_loss: 1.2509
# Epoch 13/28
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 37s 919ms/step - accuracy: 0.9146 - loss: 0.4785 - val_accuracy: 0.7219 - val_loss: 1.4122
# Epoch 14/28
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 37s 918ms/step - accuracy: 0.9235 - loss: 0.4233 - val_accuracy: 0.7563 - val_loss: 1.2428
# Epoch 15/28
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 37s 917ms/step - accuracy: 0.9370 - loss: 0.3695 - val_accuracy: 0.7812 - val_loss: 1.1039
# Epoch 16/28
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 37s 915ms/step - accuracy: 0.9600 - loss: 0.2877 - val_accuracy: 0.7500 - val_loss: 1.2665
# Epoch 17/28
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 37s 914ms/step - accuracy: 0.9603 - loss: 0.2760 - val_accuracy: 0.7281 - val_loss: 1.3860
# Epoch 17: early stopping
# Restoring model weights from the end of the best epoch: 7.

# %%
for layer in base_model.layers[-150:]:
    layer.trainable=True

for layer in base_model.layers[:-150]:
    layer.trainable=False

model.compile(
    optimizer=Adam(learning_rate=1e-5),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)


early_stop1 = EarlyStopping(
    monitor='val_accuracy',
    patience=15,
    restore_best_weights=True,
    mode='max',
    verbose=1
)

history_finetune = model.fit(
    train_ds,
    validation_data=test_ds,
    epochs=30,
    callbacks=[early_stop1]
)
# Out:
# Epoch 1/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 114s 691ms/step - accuracy: 0.9357 - loss: 0.5243 - val_accuracy: 0.8031 - val_loss: 0.8681
# Epoch 2/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 16s 401ms/step - accuracy: 0.9357 - loss: 0.4912 - val_accuracy: 0.8125 - val_loss: 0.8520
# Epoch 3/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 17s 415ms/step - accuracy: 0.9211 - loss: 0.5394 - val_accuracy: 0.8125 - val_loss: 0.8434
# Epoch 4/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 16s 409ms/step - accuracy: 0.9377 - loss: 0.4817 - val_accuracy: 0.8125 - val_loss: 0.8338
# Epoch 5/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 16s 398ms/step - accuracy: 0.9360 - loss: 0.4834 - val_accuracy: 0.8188 - val_loss: 0.8272
# Epoch 6/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 16s 390ms/step - accuracy: 0.9423 - loss: 0.4877 - val_accuracy: 0.8219 - val_loss: 0.8184
# Epoch 7/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 16s 389ms/step - accuracy: 0.9482 - loss: 0.4370 - val_accuracy: 0.8219 - val_loss: 0.8139
# Epoch 8/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 16s 400ms/step - accuracy: 0.9481 - loss: 0.4483 - val_accuracy: 0.8188 - val_loss: 0.8095
# Epoch 9/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 16s 406ms/step - accuracy: 0.9458 - loss: 0.4461 - val_accuracy: 0.8313 - val_loss: 0.8060
# Epoch 10/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 16s 393ms/step - accuracy: 0.9560 - loss: 0.4444 - val_accuracy: 0.8281 - val_loss: 0.8007
# Epoch 11/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 16s 390ms/step - accuracy: 0.9518 - loss: 0.4218 - val_accuracy: 0.8313 - val_loss: 0.8003
# Epoch 12/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 16s 400ms/step - accuracy: 0.9586 - loss: 0.4080 - val_accuracy: 0.8375 - val_loss: 0.7961
# Epoch 13/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 16s 398ms/step - accuracy: 0.9637 - loss: 0.4074 - val_accuracy: 0.8375 - val_loss: 0.7955
# Epoch 14/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 16s 395ms/step - accuracy: 0.9645 - loss: 0.3973 - val_accuracy: 0.8375 - val_loss: 0.7925
# Epoch 15/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 16s 398ms/step - accuracy: 0.9553 - loss: 0.3886 - val_accuracy: 0.8438 - val_loss: 0.7899
# Epoch 16/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 16s 398ms/step - accuracy: 0.9670 - loss: 0.3887 - val_accuracy: 0.8469 - val_loss: 0.7869
# Epoch 17/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 16s 396ms/step - accuracy: 0.9648 - loss: 0.3893 - val_accuracy: 0.8406 - val_loss: 0.7806
# Epoch 18/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 16s 398ms/step - accuracy: 0.9674 - loss: 0.4022 - val_accuracy: 0.8469 - val_loss: 0.7816
# Epoch 19/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 16s 394ms/step - accuracy: 0.9658 - loss: 0.3821 - val_accuracy: 0.8469 - val_loss: 0.7780
# Epoch 20/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 16s 392ms/step - accuracy: 0.9630 - loss: 0.3971 - val_accuracy: 0.8469 - val_loss: 0.7794
# Epoch 21/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 16s 391ms/step - accuracy: 0.9639 - loss: 0.3857 - val_accuracy: 0.8469 - val_loss: 0.7791
# Epoch 22/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 16s 393ms/step - accuracy: 0.9702 - loss: 0.3639 - val_accuracy: 0.8469 - val_loss: 0.7775
# Epoch 23/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 16s 394ms/step - accuracy: 0.9655 - loss: 0.3803 - val_accuracy: 0.8469 - val_loss: 0.7767
# Epoch 24/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 16s 395ms/step - accuracy: 0.9786 - loss: 0.3474 - val_accuracy: 0.8438 - val_loss: 0.7731
# Epoch 25/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 16s 395ms/step - accuracy: 0.9714 - loss: 0.3463 - val_accuracy: 0.8469 - val_loss: 0.7733
# Epoch 26/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 16s 396ms/step - accuracy: 0.9742 - loss: 0.3765 - val_accuracy: 0.8438 - val_loss: 0.7750
# Epoch 27/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 16s 396ms/step - accuracy: 0.9774 - loss: 0.3395 - val_accuracy: 0.8469 - val_loss: 0.7713
# Epoch 28/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 16s 396ms/step - accuracy: 0.9690 - loss: 0.3590 - val_accuracy: 0.8438 - val_loss: 0.7712
# Epoch 29/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 16s 396ms/step - accuracy: 0.9791 - loss: 0.3380 - val_accuracy: 0.8438 - val_loss: 0.7712
# Epoch 30/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 16s 396ms/step - accuracy: 0.9750 - loss: 0.3229 - val_accuracy: 0.8438 - val_loss: 0.7696
# Restoring model weights from the end of the best epoch: 16.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))
plt.plot(history_finetune.history['accuracy'], label='Train Accuracy')
plt.plot(history_finetune.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 5))
plt.plot(history_finetune.history['loss'], label='Train Loss')
plt.plot(history_finetune.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()
